# %%
import pandas as pd
import numpy as np
df=pd.read_csv('bpp_training_data.csv')
df.head(100)
# Out:
#     SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 0   1646770     9500.0    1126363     8434         132            17
# 1   1821514    14000.0    1194089    10150         132            31
# 2   1505138    50000.0    1473654     4139         132            31
# 3   1671174    16000.0    1327630     8591         132            31
# 4   1329056    22000.0    1336053     4089         132            31
# ..      ...        ...        ...      ...         ...           ...
# 95  1449641    11750.0     492948     3356         132            31
# 96  1328950    19000.0    1444418     4089         132            31
# 97  1371695    28000.0    1444477     1571         132            31
# 98  1729063    48000.0    1059447     9113         132            32
# 99  1257862    25000.0    1363747     6589         132            32
#
#     YearMade  MachineHoursCurrentMeter  UsageBand  fiModelDesc  ...  \
# 0       1974                        17          0         4593  ...
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#seperating output variable
x=df.drop(['SalePrice'],axis=1)
x
# Out:
#         SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0       1646770    1126363     8434         132            17      1974
# 1       1821514    1194089    10150         132            31      1980
# 2       1505138    1473654     4139         132            31      1978
# 3       1671174    1327630     8591         132            31      1980
# 4       1329056    1336053     4089         132            31      1984
# ...         ...        ...      ...         ...           ...       ...
# 299995  2192279    1701366     6272         136            78      1000
# 299996  2192338    1787662    12919         136            78      1000
# 299997  2433168    1714162     9580         136            78      2005
# 299998  1586638    1386512    11398         132            78      2005
# 299999  2396198    1082033     2144         136            78      2005
#
#         MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# ...

# %%
#assingning output variable
y=df.SalePrice
y
# Out:
# 0          9500.0
# 1         14000.0
# 2         50000.0
# 3         16000.0
# 4         22000.0
#            ...
# 299995    16500.0
# 299996    17000.0
# 299997    11500.0
# 299998    32000.0
# 299999    47500.0
# Name: SalePrice, Length: 300000, dtype: float64

# %%
from  sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
X_train_scaled = ss.fit_transform(x_train)
X_test_scaled = ss.transform(x_test)

# %%
#model building
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred=lr.predict(x_train)
y_test_pred=lr.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score
from math import sqrt
lr_train_mse = sqrt(mean_squared_error(y_train, y_train_pred))
lr_train_r2 = r2_score(y_train, y_train_pred)
lr_test_mse = sqrt(mean_squared_error(y_test, y_test_pred))
lr_test_r2 = r2_score(y_test, y_test_pred)

# %%
print(lr_train_mse)
# Out:
# 17438.677440685082

# %%
print(lr_test_mse)
# Out:
# 17436.22803727859

# %%
print(lr_test_r2)
# Out:
# 0.4132835460852331

# %%
#lasso regression
from sklearn.linear_model import Lasso
a=Lasso()
a.fit(X_train_scaled,y_train)
# Out:
# Lasso()

# %%
y_train_pred=a.predict(X_train_scaled)
y_test_pred=a.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error,r2_score
from math import sqrt
a_train_mse = sqrt(mean_squared_error(y_train, y_train_pred))
a_train_r2 = r2_score(y_train, y_train_pred)
a_test_mse = sqrt(mean_squared_error(y_test, y_test_pred))
a_test_r2 = r2_score(y_test, y_test_pred)
a_test_r2
# Out:
# 0.4132515791418693

# %%
#ridge regression
from sklearn.linear_model import Ridge
b=Ridge()
b.fit(X_train_scaled,y_train)
# Out:
# Ridge()

# %%
y_train_pred=b.predict(X_train_scaled)
y_test_pred=b.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error,r2_score
from math import sqrt
b_train_mse = sqrt(mean_squared_error(y_train, y_train_pred))
b_train_r2 = r2_score(y_train, y_train_pred)
b_test_mse = sqrt(mean_squared_error(y_test, y_test_pred))
b_test_r2 = r2_score(y_test, y_test_pred)
b_test_r2
# Out:
# 0.413281674949428

# %%
#random forest
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=5)
regressor.fit(x_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=5)

# %%
y_pred=regressor.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8828116397532522
