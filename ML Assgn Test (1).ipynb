# %%
import pandas as pd
import numpy as np
df=pd.read_csv('bpp_training_data.csv')
df.head(100)
# Out:
#     SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 0   1646770     9500.0    1126363     8434         132            17
# 1   1821514    14000.0    1194089    10150         132            31
# 2   1505138    50000.0    1473654     4139         132            31
# 3   1671174    16000.0    1327630     8591         132            31
# 4   1329056    22000.0    1336053     4089         132            31
# ..      ...        ...        ...      ...         ...           ...
# 95  1449641    11750.0     492948     3356         132            31
# 96  1328950    19000.0    1444418     4089         132            31
# 97  1371695    28000.0    1444477     1571         132            31
# 98  1729063    48000.0    1059447     9113         132            32
# 99  1257862    25000.0    1363747     6589         132            32
#
#     YearMade  MachineHoursCurrentMeter  UsageBand  fiModelDesc  ...  \
# 0       1974                        17          0         4593  ...
# 1       1980                        31          0         1820  ...
# 2       1978                        31          0         2348  ...
# 3       1980                        31          0         1819  ...
# 4       1984                        31          0         2119  ...
# ..       ...                       ...        ...          ...  ...
# 95      1966                        31          0           82  ...
# 96      1983                        31          0         2119  ...
# 97      1982                        31          0         2211  ...
# 98      1984                        32          0         4815  ...
# 99      1983                        32          0          112  ...
#
#     Grouser_Type  Backhoe_Mounting  Blade_Type  Travel_Controls  \
# 0              0                 1           8                6
# 1              0                 0           0                0
# 2              0                 1           8                6
# 3              0                 0           0                0
# 4              0                 1           6                5
# ..           ...               ...         ...              ...
# 95             0                 0           0                0
# 96             0                 1           6                6
# 97             0                 1           8                6
# 98             0                 0           0                0
# 99             0                 1           6                6
#
#     Differential_Type  Steering_Controls  saleYear  saleMonth  saleDay  \
# 0                   0                  0      1989          1       17
# 1                   4                  2      1989          1       31
# 2                   0                  0      1989          1       31
# 3                   4                  2      1989          1       31
# 4                   0                  0      1989          1       31
# ..                ...                ...       ...        ...      ...
# 95                  0                  0      1989          1       31
# 96                  0                  0      1989          1       31
# 97                  0                  0      1989          1       31
# 98                  0                  0      1989          2        1
# 99                  0                  0      1989          2        1
#
#     saleDayOfYear
# 0              17
# 1              31
# 2              31
# 3              31
# 4              31
# ..            ...
# 95             31
# 96             31
# 97             31
# 98             32
# 99             32
#
# [100 rows x 56 columns]

# %%
import pandas as pd
test=pd.read_csv('bpp_test.csv')
test.head()
# Out:
#    SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  2281791     891349     1634         136            78      2003
# 1  2192394    1726692    12924         136            78      1000
# 2  2369596    1122452    15044         136            78      1994
# 3  2233945      92096     3858         136            78      1999
# 4  2433167    1696810     9580         136            78      2005
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 0                        78          0         2330          706  ...
# 1                        78          0         4498         1672  ...
# 2                        78          0         2644          827  ...
# 3                        78          0         1772          535  ...
# 4                        78          0         4514         1684  ...
#
#    Grouser_Type  Backhoe_Mounting  Blade_Type  Travel_Controls  \
# 0             0                 1           7                6
# 1             0                 0           0                0
# 2             3                 0           0                0
# 3             0                 0           0                0
# 4             0                 0           0                0
#
#    Differential_Type  Steering_Controls  saleYear  saleMonth  saleDay  \
# 0                  0                  0      2009          3       19
# 1                  0                  0      2009          3       19
# 2                  0                  0      2009          3       19
# 3                  4                  2      2009          3       19
# 4                  0                  0      2009          3       19
#
#    saleDayOfYear
# 0             78
# 1             78
# 2             78
# 3             78
# 4             78
#
# [5 rows x 55 columns]

# %%
train_len=len(df)
test_len=len(test)

# %%
a=pd.concat([df,test],axis=0)
a.reset_index(drop=True,inplace=True)
a.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1646770     9500.0    1126363     8434         132            17      1974
# 1  1821514    14000.0    1194089    10150         132            31      1980
# 2  1505138    50000.0    1473654     4139         132            31      1978
# 3  1671174    16000.0    1327630     8591         132            31      1980
# 4  1329056    22000.0    1336053     4089         132            31      1984
#
#    MachineHoursCurrentMeter  UsageBand  fiModelDesc  ...  Grouser_Type  \
# 0                        17          0         4593  ...             0
# 1                        31          0         1820  ...             0
# 2                        31          0         2348  ...             0
# 3                        31          0         1819  ...             0
# 4                        31          0         2119  ...             0
#
#    Backhoe_Mounting  Blade_Type  Travel_Controls  Differential_Type  \
# 0                 1           8                6                  0
# 1                 0           0                0                  4
# 2                 1           8                6                  0
# 3                 0           0                0                  4
# 4                 1           6                5                  0
#
#    Steering_Controls  saleYear  saleMonth  saleDay  saleDayOfYear
# 0                  0      1989          1       17             17
# 1                  2      1989          1       31             31
# 2                  0      1989          1       31             31
# 3                  2      1989          1       31             31
# 4                  0      1989          1       31             31
#
# [5 rows x 56 columns]

# %%
train=a.iloc[:train_len,:]
test_set=a.iloc[train_len:,:]

# %%
d=test_set.drop(['SalePrice'],axis=1)
d
# Out:
#         SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 300000  2281791     891349     1634         136            78      2003
# 300001  2192394    1726692    12924         136            78      1000
# 300002  2369596    1122452    15044         136            78      1994
# 300003  2233945      92096     3858         136            78      1999
# 300004  2433167    1696810     9580         136            78      2005
# ...         ...        ...      ...         ...           ...       ...
# 412693  6302984    1915521     5266         149           119      2001
# 412694  6324811    1919104    19330         149           119      2004
# 412695  6313029    1918416    17244         149           119      2004
# 412696  6266251     509560     3357         149           119      1993
# 412697  6283635    1869284     4701         149           119      1000
#
#         MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 300000                        78          0         2330          706  ...
# 300001                        78          0         4498         1672  ...
# 300002                        78          0         2644          827  ...
# 300003                        78          0         1772          535  ...
# 300004                        78          0         4514         1684  ...
# ...                          ...        ...          ...          ...  ...
# 412693                       119          0         2101          690  ...
# 412694                       119          0          240           84  ...
# 412695                       119          0          627          203  ...
# 412696                       119          0           83           19  ...
# 412697                       119          0          989          307  ...
#
#         Grouser_Type  Backhoe_Mounting  Blade_Type  Travel_Controls  \
# 300000             0                 1           7                6
# 300001             0                 0           0                0
# 300002             3                 0           0                0
# 300003             0                 0           0                0
# 300004             0                 0           0                0
# ...              ...               ...         ...              ...
# 412693             0                 1           6                6
# 412694             0                 0           0                0
# 412695             0                 0           0                0
# 412696             0                 0           0                0
# 412697             0                 0           0                0
#
#         Differential_Type  Steering_Controls  saleYear  saleMonth  saleDay  \
# 300000                  0                  0      2009          3       19
# 300001                  0                  0      2009          3       19
# 300002                  0                  0      2009          3       19
# 300003                  4                  2      2009          3       19
# 300004                  0                  0      2009          3       19
# ...                   ...                ...       ...        ...      ...
# 412693                  0                  0      2012          4       28
# 412694                  0                  0      2012          4       28
# 412695                  0                  0      2012          4       28
# 412696                  0                  0      2012          4       28
# 412697                  4                  2      2012          4       28
#
#         saleDayOfYear
# 300000             78
# 300001             78
# 300002             78
# 300003             78
# 300004             78
# ...               ...
# 412693            119
# 412694            119
# 412695            119
# 412696            119
# 412697            119
#
# [112698 rows x 55 columns]

# %%
#seperating output variable
x=train.drop(['SalePrice'],axis=1)
x
# Out:
#         SalesID  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0       1646770    1126363     8434         132            17      1974
# 1       1821514    1194089    10150         132            31      1980
# 2       1505138    1473654     4139         132            31      1978
# 3       1671174    1327630     8591         132            31      1980
# 4       1329056    1336053     4089         132            31      1984
# ...         ...        ...      ...         ...           ...       ...
# 299995  2192279    1701366     6272         136            78      1000
# 299996  2192338    1787662    12919         136            78      1000
# 299997  2433168    1714162     9580         136            78      2005
# 299998  1586638    1386512    11398         132            78      2005
# 299999  2396198    1082033     2144         136            78      2005
#
#         MachineHoursCurrentMeter  UsageBand  fiModelDesc  fiBaseModel  ...  \
# 0                             17          0         4593         1744  ...
# 1                             31          0         1820          559  ...
# 2                             31          0         2348          713  ...
# 3                             31          0         1819          558  ...
# 4                             31          0         2119          683  ...
# ...                          ...        ...          ...          ...  ...
# 299995                        78          0         4215         1500  ...
# 299996                        78          0         4216         1501  ...
# 299997                        78          0         4514         1684  ...
# 299998                        78          3         1202          354  ...
# 299999                        78          3         4378         1594  ...
#
#         Grouser_Type  Backhoe_Mounting  Blade_Type  Travel_Controls  \
# 0                  0                 1           8                6
# 1                  0                 0           0                0
# 2                  0                 1           8                6
# 3                  0                 0           0                0
# 4                  0                 1           6                5
# ...              ...               ...         ...              ...
# 299995             0                 0           0                0
# 299996             0                 0           0                0
# 299997             0                 0           0                0
# 299998             0                 1           6                6
# 299999             1                 0           0                0
#
#         Differential_Type  Steering_Controls  saleYear  saleMonth  saleDay  \
# 0                       0                  0      1989          1       17
# 1                       4                  2      1989          1       31
# 2                       0                  0      1989          1       31
# 3                       4                  2      1989          1       31
# 4                       0                  0      1989          1       31
# ...                   ...                ...       ...        ...      ...
# 299995                  0                  0      2009          3       19
# 299996                  0                  0      2009          3       19
# 299997                  0                  0      2009          3       19
# 299998                  0                  0      2009          3       19
# 299999                  0                  0      2009          3       19
#
#         saleDayOfYear
# 0                  17
# 1                  31
# 2                  31
# 3                  31
# 4                  31
# ...               ...
# 299995             78
# 299996             78
# 299997             78
# 299998             78
# 299999             78
#
# [300000 rows x 55 columns]

# %%
#assingning output variable
y=train.SalePrice
y
# Out:
# 0          9500.0
# 1         14000.0
# 2         50000.0
# 3         16000.0
# 4         22000.0
#            ...
# 299995    16500.0
# 299996    17000.0
# 299997    11500.0
# 299998    32000.0
# 299999    47500.0
# Name: SalePrice, Length: 300000, dtype: float64

# %%
#model building
# from sklearn.linear_model import LinearRegression
# lr=LinearRegression()
# lr.fit(x_train,y_train)

# %%
# y_train_pred=lr.predict(x_train)
# y_test_pred=lr.predict(x_test)

# %%
# from sklearn.metrics import mean_squared_error,r2_score
# from math import sqrt
# lr_train_mse = sqrt(mean_squared_error(y_train, y_train_pred))
# lr_train_r2 = r2_score(y_train, y_train_pred)
# lr_test_mse = sqrt(mean_squared_error(y_test, y_test_pred))
# lr_test_r2 = r2_score(y_test, y_test_pred)

# %%
# print(lr_train_mse)

# %%
# print(lr_test_mse)

# %%
# print(lr_test_r2)

# %%
#random forest
# from sklearn.ensemble import RandomForestRegressor
# regressor=RandomForestRegressor(n_estimators=5)
# regressor.fit(x_train,y_train)

# %%
# y_pred=regressor.predict(x_test)
# from sklearn.metrics import r2_score
# r2_score(y_test, y_pred)

# %%
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators = 5)
regressor.fit(x,y)
# Out:
# RandomForestRegressor(n_estimators=5)

# %%
pre = regressor.predict(d)
pre
# Out:
# array([67300., 17800., 17100., ..., 25900., 49300., 35300.])

# %%
s = pd.DataFrame()
s['Saleprice'] = pre
s
# Out:
#         Saleprice
# 0         67300.0
# 1         17800.0
# 2         17100.0
# 3         69500.0
# 4         11500.0
# ...           ...
# 112693    16450.0
# 112694    10400.0
# 112695    25900.0
# 112696    49300.0
# 112697    35300.0
#
# [112698 rows x 1 columns]

# %%
s.to_csv('AI_039.csv',index = False)
